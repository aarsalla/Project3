# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np


import requests
import pymongo

# SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
Base = declarative_base()

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Set path 
import sys


# Config variables
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd

# Import Pandas
import pandas as pd

import datetime
from time import gmtime, strftime, strptime
from datetime import timedelta
import requests
import json

# %%
aengine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")
aconn = aengine.connect()
aengine
# Out:
# Engine(mysql://root:***@codingbootcamp.ctxjv3tnsa2p.us-east-2.rds.amazonaws.com:3306/gwsis)

# %%
master_15_day = pd.read_sql('SELECT * FROM master_15_day',aconn)
master_30_day = pd.read_sql('SELECT * FROM master_30_day',aconn)
master_45_day = pd.read_sql('SELECT * FROM master_45_day',aconn)
master_60_day = pd.read_sql('SELECT * FROM master_60_day',aconn)

# %%
correlation_30 = master_30_day.drop(['index','Stock Name','Reported Date','30 Days'],axis=1)
correlation_30.loc[correlation_30['30 Days Later Stock Price'] == 'N/A','30 Days Later Stock Price'] = np.nan
correlation_30 = correlation_30.dropna()

# %%
for x in correlation_30.columns:
    correlation_30[x] = pd.to_numeric(correlation_30[x])

# %%
correlation_30.corr()
# Out:
#                                Earnings Date Stock Price  \
# Earnings Date Stock Price                       1.000000
# 30 Days Later Stock Price                       0.996611
# Chaikin A/D line                                0.049025
# ADX                                            -0.011121
# Aroon Up                                        0.033882
# Aroon Down                                     -0.052323
# Lower Band                                      0.997825
# Middle Band                                     0.998260
# Upper Band                                      0.997470
# Lower Band (5)                                  0.998980
# Middle Band (5)                                 0.999299
# Upper Band (5)                                  0.998932
# CCI                                             0.040725
# Earnings Per Share                              0.747473
# Forecasted Earnings Per Share                   0.706390
# % Surprise                                      0.076320
# EMA (20 Day)                                    0.998443
# MACD_Hist                                       0.160987
# MACD_Signal                                     0.190816
# MACD                                            0.221527
# OBV                                             0.024169
# RSI                                             0.056522
# 20 Day Moving Average                           0.998260
# 5 Day Moving Average                            0.999299
# SlowD                                           0.030215
# SlowK                                           0.024116
#
#                                30 Days Later Stock Price  Chaikin A/D line  \
# Earnings Date Stock Price                       0.996611          0.049025
# 30 Days Later Stock Price                       1.000000          0.049195
# Chaikin A/D line                                0.049195          1.000000
# ADX                                            -0.013408          0.006278
# Aroon Up                                        0.035121          0.011029
# Aroon Down                                     -0.056044         -0.036935
# Lower Band                                      0.994192          0.048137
# Middle Band                                     0.994297          0.048296
# Upper Band                                      0.993216          0.048382
# Lower Band (5)                                  0.996014          0.048092
# Middle Band (5)                                 0.996272          0.047989
# Upper Band (5)                                  0.995849          0.047860
# CCI                                             0.041979          0.018035
# Earnings Per Share                              0.749424          0.008391
# CCI                               0.004465    0.001910        0.022730
# Earnings Per Share                0.750750    0.746279        0.751727
# Forecasted Earnings Per Share     0.709472    0.704577        0.711091
# % Surprise                        0.075298    0.076808        0.074394
# EMA (20 Day)                      0.999945    0.999391        0.998792
# MACD_Hist                         0.111540    0.108307        0.147217
# MACD_Signal                       0.164898    0.153725        0.196664
# MACD                              0.183102    0.172003        0.222663
# OBV                               0.023023    0.023385        0.023456
# RSI                               0.018485    0.013996        0.041187
# 20 Day Moving Average             1.000000    0.999441        0.998581
# 5 Day Moving Average              0.999282    0.998374        0.999634
# SlowD                             0.004713    0.002053        0.025083
# SlowK                            -0.004314   -0.006634        0.012818
#
#                                  ...     EMA (20 Day)  MACD_Hist  MACD_Signal  \
# Earnings Date Stock Price        ...         0.998443   0.160987     0.190816
# 30 Days Later Stock Price        ...         0.994771   0.177016     0.202155
# Chaikin A/D line                 ...         0.048235   0.001186     0.012908
# ADX                              ...        -0.002380  -0.122190    -0.200063
# Aroon Up                         ...         0.013520   0.229086     0.411562
# Aroon Down                       ...        -0.029348  -0.322823    -0.406697
# Lower Band                       ...         0.999244   0.115002     0.177155
# Middle Band                      ...         0.999945   0.111540     0.164898
# Upper Band                       ...         0.999391   0.108307     0.153725
# Lower Band (5)                   ...         0.998792   0.147217     0.196664
# Middle Band (5)                  ...         0.999465   0.142221     0.188351
# Upper Band (5)                   ...         0.999430   0.137434     0.180418
# CCI                              ...         0.006294   0.516736     0.196140
# Earnings Per Share               ...         0.751072   0.139128     0.045035
# Forecasted Earnings Per Share    ...         0.709914   0.150444     0.028010
# % Surprise                       ...         0.075677  -0.003834     0.024349
# EMA (20 Day)                     ...         1.000000   0.118657     0.163891
# MACD_Hist                        ...         0.118657   1.000000     0.160529
# MACD_Signal                      ...         0.163891   0.160529     1.000000
# MACD                             ...         0.184341   0.447678     0.954464
# OBV                              ...         0.023114   0.008122     0.004293
# RSI                              ...         0.020020   0.509634     0.354783
# 20 Day Moving Average            ...         0.999945   0.111540     0.164898
# 5 Day Moving Average             ...         0.999465   0.142221     0.188351
# SlowD                            ...         0.007057   0.510935     0.167758
# SlowK                            ...        -0.002551   0.502608     0.116573
#
#                                    MACD       OBV       RSI  \
# Earnings Date Stock Price      0.221527  0.024169  0.056522
# 30 Days Later Stock Price      0.236645  0.021790  0.057288
# Chaikin A/D line               0.012053 -0.358424  0.029038
# ADX                           -0.218178 -0.025820 -0.209584
# Aroon Up                       0.442093 -0.021072  0.617268
# Aroon Down                    -0.466017  0.008010 -0.659257
# Lower Band                     0.195252  0.022587  0.023472
# Middle Band                    0.183102  0.023023  0.018485
# Upper Band                     0.172003  0.023385  0.013996
# Lower Band (5)                 0.222663  0.023456  0.041187
# Middle Band (5)                0.213623  0.023030  0.037639
# Upper Band (5)                 0.204989  0.022616  0.034281
# CCI                            0.333875  0.001868  0.885040
# Earnings Per Share             0.082851  0.003961 -0.006343
# Forecasted Earnings Per Share  0.070847 -0.002780 -0.014191
# % Surprise                     0.020901  0.023749  0.042384
# EMA (20 Day)                   0.184341  0.023114  0.020020
# MACD_Hist                      0.447678  0.008122  0.509634
# MACD_Signal                    0.954464  0.004293  0.354783
# MACD                           1.000000  0.006344  0.475449
# OBV                            0.006344  1.000000  0.006176
# RSI                            0.475449  0.006176  1.000000
# 20 Day Moving Average          0.183102  0.023023  0.018485
# 5 Day Moving Average           0.213623  0.023030  0.037639
# SlowD                          0.306409 -0.002923  0.633677
# SlowK                          0.257521  0.001688  0.709123
#
#                                20 Day Moving Average  5 Day Moving Average  \
# Earnings Date Stock Price                   0.998260              0.999299
# 30 Days Later Stock Price                   0.994297              0.996272
# Chaikin A/D line                            0.048296              0.047989
# ADX                                        -0.001779             -0.009484
# Aroon Up                                    0.013564              0.027352
# Aroon Down                                 -0.028332             -0.044896
# Lower Band                                  0.999304              0.998977
# Middle Band                                 1.000000              0.999282
# Upper Band                                  0.999441              0.998374
# Lower Band (5)                              0.998581              0.999634
# Middle Band (5)                             0.999282              1.000000
# Upper Band (5)                              0.999274              0.999677
# CCI                                         0.004465              0.020091
# Earnings Per Share                          0.750750              0.750738
# Forecasted Earnings Per Share               0.709472              0.709820
# % Surprise                                  0.075298              0.075201
# EMA (20 Day)                                0.999945              0.999465
# MACD_Hist                                   0.111540              0.142221
# MACD_Signal                                 0.164898              0.188351
# MACD                                        0.183102              0.213623
# OBV                                         0.023023              0.023030
# RSI                                         0.018485              0.037639
# 20 Day Moving Average                       1.000000              0.999282
# 5 Day Moving Average                        0.999282              1.000000
# SlowD                                       0.004713              0.022196
# SlowK                                      -0.004314              0.010270
#
#                                   SlowD     SlowK
# Earnings Date Stock Price      0.030215  0.024116
# 30 Days Later Stock Price      0.032817  0.024788
# Chaikin A/D line               0.028112  0.052826
# ADX                           -0.127219 -0.101925
# Aroon Up                       0.383605  0.341009
# Aroon Down                    -0.439034 -0.383640
# Lower Band                     0.007677 -0.001719
# Middle Band                    0.004713 -0.004314
# Upper Band                     0.002053 -0.006634
# Lower Band (5)                 0.025083  0.012818
# Middle Band (5)                0.022196  0.010270
# Upper Band (5)                 0.019470  0.007871
# CCI                            0.578300  0.674746
# Earnings Per Share             0.004947  0.002295
# Forecasted Earnings Per Share  0.008054  0.003210
# % Surprise                    -0.025055 -0.013363
# EMA (20 Day)                   0.007057 -0.002551
# MACD_Hist                      0.510935  0.502608
# MACD_Signal                    0.167758  0.116573
# MACD                           0.306409  0.257521
# OBV                           -0.002923  0.001688
# RSI                            0.633677  0.709123
# 20 Day Moving Average          0.004713 -0.004314
# 5 Day Moving Average           0.022196  0.010270
# SlowD                          1.000000  0.893703
# SlowK                          0.893703  1.000000
#
# [26 rows x 26 columns]
