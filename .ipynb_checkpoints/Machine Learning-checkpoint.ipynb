# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np


import requests
import pymongo

# SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
Base = declarative_base()

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Set path 
import sys


# Config variables
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd

# Import Pandas
import pandas as pd

import datetime
from time import gmtime, strftime, strptime
from datetime import timedelta
import requests
import json
import statsmodels.api as sm
from scipy import stats
from sklearn import datasets, linear_model

# %%
aengine = create_engine(f"mysql://{remote_gwsis_dbuser}:stockholders@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")
aconn = aengine.connect()
aengine
# Out:
# Engine(mysql://root:***@codingbootcamp.ctxjv3tnsa2p.us-east-2.rds.amazonaws.com:3306/gwsis)

# %%
master_15_day = pd.read_sql('SELECT * FROM master_15_day',aconn)
master_30_day = pd.read_sql('SELECT * FROM master_30_day',aconn)
master_45_day = pd.read_sql('SELECT * FROM master_45_day',aconn)
master_60_day = pd.read_sql('SELECT * FROM master_60_day',aconn)

# %%
correlation_30 = master_30_day.drop(['index','Stock Name','Reported Date','30 Days'],axis=1)
correlation_30.loc[correlation_30['30 Days Later Stock Price'] == 'N/A','30 Days Later Stock Price'] = np.nan
correlation_30 = correlation_30.dropna()

# %%
for x in correlation_30.columns:
    correlation_30[x] = pd.to_numeric(correlation_30[x])

# %%
correlation_30.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = correlation_30[['Earnings Date Stock Price','20 Day Moving Average','5 Day Moving Average',
                  '% Surprise','Lower Band (5)','Upper Band (5)']]
y = correlation_30['30 Days Later Stock Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# 0.9926243672478898

# %%
model.coef_
# Out:
# array([ 0.61312111, -0.93222073,  0.42894001,  0.00737199,  0.30464495,
#         0.55323507])

# %%
correlation_30['Difference'] = ((correlation_30['30 Days Later Stock Price'] - correlation_30['Earnings Date Stock Price'])/correlation_30['Earnings Date Stock Price'])*100

# %%
x = [[55.36,61.7470, 61.3720,-3.53]]

# %%
results = model.predict(X_test)

# %%
master_30_day.iloc[383]
# Out:
# index                                       383
# Stock Name                                  WBA
# Reported Date                        04/02/2019
# 30 Days                              04/30/2019
# Earnings Date Stock Price                 55.36
# 30 Days Later Stock Price                 53.57
# Chaikin A/D line                 487937716.8485
# ADX                                     29.3845
# Aroon Up                                 8.0000
# Aroon Down                             100.0000
# Lower Band                              58.0593
# Middle Band                             61.7470
# Upper Band                              65.4347
# Lower Band (5)                          55.2883
# Middle Band (5)                         61.3720
# Upper Band (5)                          67.4557
# CCI                                   -346.6951
# Earnings Per Share                         1.64
# Forecasted Earnings Per Share               1.7
# % Surprise                                -3.53
# EMA (20 Day)                            62.9068
# MACD_Hist                               -0.0444
# MACD_Signal                             -1.7892
# MACD                                    -1.8337
# OBV                              -26937389.0000
# RSI                                     24.4231
# 20 Day Moving Average                   61.7470
# 5 Day Moving Average                    61.3720
# SlowD                                   60.4017
# SlowK                                   54.8883
# Name: 383, dtype: object

# %%
X.iloc[206]
# Out:
# Earnings Date Stock Price    72.970
# 20 Day Moving Average        73.292
# 5 Day Moving Average         72.412
# % Surprise                    1.300
# Lower Band (5)               71.279
# Upper Band (5)               73.545
# Name: 209, dtype: float64

# %%
model.predict([X.iloc[206]])
# Out:
# array([73.41226647])

# %%
df_results = pd.DataFrame({'Predictions': results, 'Actual': y_test, 'Stock Price': X_test['Earnings Date Stock Price']})

# %%
df_results.to_csv('results.csv')

# %%
results
# Out:
# array([76.89368033, 26.35757934, 99.77522261, ..., 66.56325988,
#        46.6630785 , 80.86429267])

# %%
y_test.iloc[208]
# Out:
# 184.31

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     30 Days Later Stock Price   R-squared:                       0.994
# Model:                                   OLS   Adj. R-squared:                  0.994
# Method:                        Least Squares   F-statistic:                 5.827e+04
# Date:                       Sun, 05 May 2019   Prob (F-statistic):               0.00
# Time:                               09:23:20   Log-Likelihood:                -6678.0
# No. Observations:                       1722   AIC:                         1.337e+04
# Df Residuals:                           1716   BIC:                         1.340e+04
# Df Model:                                  5
# Covariance Type:                   nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         2.9156      0.355      8.218      0.000       2.220       3.611
# Earnings Date Stock Price     0.5553      0.050     11.038      0.000       0.457       0.654
# 20 Day Moving Average        -0.8142      0.053    -15.347      0.000      -0.918      -0.710
# 5 Day Moving Average          0.4107      0.027     15.392      0.000       0.358       0.463
# % Surprise                    0.0137      0.008      1.643      0.101      -0.003       0.030
# Lower Band (5)                0.2784      0.041      6.783      0.000       0.198       0.359
# Upper Band (5)                0.5431      0.050     10.891      0.000       0.445       0.641
# ==============================================================================
# Omnibus:                      515.119   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41370.514
# Skew:                          -0.417   Prob(JB):                         0.00
# Kurtosis:                      26.998   Cond. No.                     1.65e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.15e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model.coef_
# Out:
# array([ 0.959566  , -0.57947408,  0.2004038 ,  0.01120735,  0.14856972,
#         0.25223789])

# %%
model.intercept_
# Out:
# 2.7127034017417913

# %%
correlation_45 = master_45_day.drop(['index','Stock Name','Reported Date','45 Days'],axis=1)
correlation_45.loc[correlation_45['45 Days Later Stock Price'] == 'N/A','45 Days Later Stock Price'] = np.nan
correlation_45 = correlation_45.dropna()

# %%
for x in correlation_45.columns:
    correlation_45[x] = pd.to_numeric(correlation_45[x])

# %%
X = correlation_45[['Earnings Date Stock Price','20 Day Moving Average', '5 Day Moving Average',
                  'Lower Band (5)','Earnings Per Share','Aroon Down','% Surprise']]
y = correlation_45['45 Days Later Stock Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# 0.9864762584996047

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     45 Days Later Stock Price   R-squared:                       0.992
# Model:                                   OLS   Adj. R-squared:                  0.992
# Method:                        Least Squares   F-statistic:                 3.491e+04
# Date:                       Mon, 06 May 2019   Prob (F-statistic):               0.00
# Time:                               08:37:34   Log-Likelihood:                -6899.5
# No. Observations:                       1703   AIC:                         1.381e+04
# Df Residuals:                           1696   BIC:                         1.385e+04
# Df Model:                                  6
# Covariance Type:                   nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         3.9587      0.645      6.134      0.000       2.693       5.224
# Earnings Date Stock Price     0.5010      0.061      8.265      0.000       0.382       0.620
# 20 Day Moving Average        -0.6401      0.066     -9.768      0.000      -0.769      -0.512
# 5 Day Moving Average          1.1527      0.096     12.008      0.000       0.964       1.341
# Earnings Per Share           -2.4278      0.287     -8.468      0.000      -2.990      -1.866
# Aroon Down                   -0.0123      0.010     -1.250      0.211      -0.032       0.007
# % Surprise                    0.0169      0.010      1.699      0.089      -0.003       0.036
# ==============================================================================
# Omnibus:                      580.799   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43720.969
# Skew:                           0.686   Prob(JB):                         0.00
# Kurtosis:                      27.784   Cond. No.                         638.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results = model.predict(X_test)

# %%
df_results = pd.DataFrame({'Predictions': results, 'Actual': y_test, 'Stock Price': X_test['Earnings Date Stock Price']})

# %%
df_results.to_csv('results_test.csv')

# %%
correlation_60 = master_60_day.drop(['index','Stock Name','Reported Date','60 Days'],axis=1)
correlation_60.loc[correlation_60['60 Days Later Stock Price'] == 'N/A','60 Days Later Stock Price'] = np.nan
correlation_60 = correlation_60.dropna()

# %%
for x in correlation_60.columns:
    correlation_60[x] = pd.to_numeric(correlation_60[x])

# %%
correlation_45.corr()
# Out:
#                                Earnings Date Stock Price  \
# Earnings Date Stock Price                       1.000000
# 45 Days Later Stock Price                       0.995433
# Chaikin A/D line                                0.048898
# ADX                                            -0.013537
# Aroon Up                                        0.034750
# Aroon Down                                     -0.051587
# Lower Band                                      0.997828
# Middle Band                                     0.998263
# Upper Band                                      0.997476
# Lower Band (5)                                  0.998983
# Middle Band (5)                                 0.999301
# Upper Band (5)                                  0.998934
# CCI                                             0.041736
# Earnings Per Share                              0.747684
# Forecasted Earnings Per Share                   0.706624
# % Surprise                                      0.076241
# EMA (20 Day)                                    0.998447
# MACD_Hist                                       0.161330
# MACD_Signal                                     0.190567
# MACD                                            0.221408
# OBV                                             0.024462
# RSI                                             0.056937
# 20 Day Moving Average                           0.998263
# 5 Day Moving Average                            0.999301
# SlowD                                           0.030758
# SlowK                                           0.024164
#
#                                45 Days Later Stock Price  Chaikin A/D line  \
# Earnings Date Stock Price                       0.995433          0.048898
# 45 Days Later Stock Price                       1.000000          0.050382
# Chaikin A/D line                                0.050382          1.000000
# ADX                                            -0.021242          0.004873
# Aroon Up                                        0.043284          0.009764
# Aroon Down                                     -0.062444         -0.035796
# Lower Band                                      0.993251          0.048019
# Middle Band                                     0.993276          0.048192
# Upper Band                                      0.992127          0.048290
# Lower Band (5)                                  0.994789          0.047991
# Middle Band (5)                                 0.995123          0.047871
# Upper Band (5)                                  0.994774          0.047727
# CCI                                             0.042562          0.017004
# Earnings Per Share                              0.732994          0.008643
# Forecasted Earnings Per Share                   0.690937          0.003070
# % Surprise                                      0.080230          0.069214
# EMA (20 Day)                                    0.993570          0.048130
# MACD_Hist                                       0.163455          0.000994
# MACD_Signal                                     0.219063          0.012498
# MACD                                            0.247865          0.011623
# OBV                                             0.023681         -0.358371
# RSI                                             0.059888          0.028233
# 20 Day Moving Average                           0.993276          0.048192
# 5 Day Moving Average                            0.995123          0.047871
# SlowD                                           0.030671          0.028990
# SlowK                                           0.021532          0.053429
#
#                                     ADX  Aroon Up  Aroon Down  Lower Band  \
# Earnings Date Stock Price     -0.013537  0.034750   -0.051587    0.997828
# 45 Days Later Stock Price        ...         0.993570   0.163455     0.219063
# Chaikin A/D line                 ...         0.048130   0.000994     0.012498
# ADX                              ...        -0.004739  -0.122820    -0.202591
# Aroon Up                         ...         0.014521   0.228125     0.411722
# Aroon Down                       ...        -0.028677  -0.322709    -0.406406
# Lower Band                       ...         0.999246   0.115398     0.176906
# Middle Band                      ...         0.999945   0.111904     0.164702
# Upper Band                       ...         0.999392   0.108643     0.153578
# Lower Band (5)                   ...         0.998793   0.147623     0.196460
# Middle Band (5)                  ...         0.999465   0.142581     0.188158
# Upper Band (5)                   ...         0.999432   0.137750     0.180236
# CCI                              ...         0.007321   0.519744     0.194523
# Earnings Per Share               ...         0.751273   0.139218     0.045444
# Forecasted Earnings Per Share    ...         0.710137   0.150572     0.028446
# % Surprise                       ...         0.075600  -0.003885     0.024230
# EMA (20 Day)                     ...         1.000000   0.119023     0.163709
# MACD_Hist                        ...         0.119023   1.000000     0.160572
# MACD_Signal                      ...         0.163709   0.160572     1.000000
# MACD                             ...         0.184287   0.447776     0.954444
# OBV                              ...         0.023428   0.008169     0.004075
# RSI                              ...         0.020505   0.511327     0.353646
# 20 Day Moving Average            ...         0.999945   0.111904     0.164702
# 5 Day Moving Average             ...         0.999465   0.142581     0.188158
# SlowD                            ...         0.007660   0.511038     0.166888
# SlowK                            ...        -0.002440   0.502799     0.115623
#
#                                    MACD       OBV       RSI  \
# Earnings Date Stock Price      0.221408  0.024462  0.056937
# 45 Days Later Stock Price      0.247865  0.023681  0.059888
# Chaikin A/D line               0.011623 -0.358371  0.028233
# ADX                           -0.220658 -0.025702 -0.212712
# Aroon Up                       0.441944 -0.020911  0.614901
# Aroon Down                    -0.465723  0.008840 -0.659743
# Lower Band                     0.195147  0.022900  0.023849
# Middle Band                    0.183034  0.023332  0.018934
# Upper Band                     0.171971  0.023691  0.014510
# Lower Band (5)                 0.222603  0.023759  0.041699
# Middle Band (5)                0.213558  0.023340  0.038126
# Upper Band (5)                 0.204920  0.022930  0.034745
# CCI                            0.333344  0.001270  0.883708
# Earnings Per Share             0.083255  0.003647 -0.005506
# Forecasted Earnings Per Share  0.071289 -0.003128 -0.013300
# % Surprise                     0.020776  0.023820  0.042470
# EMA (20 Day)                   0.184287  0.023428  0.020505
# MACD_Hist                      0.447776  0.008169  0.511327
# MACD_Signal                    0.954444  0.004075  0.353646
# MACD                           1.000000  0.006161  0.474949
# OBV                            0.006161  1.000000  0.005397
# RSI                            0.474949  0.005397  1.000000
# 20 Day Moving Average          0.183034  0.023332  0.018934
# 5 Day Moving Average           0.213558  0.023340  0.038126
# SlowD                          0.305678 -0.003384  0.634660
# SlowK                          0.256746  0.001083  0.710644
#
#                                20 Day Moving Average  5 Day Moving Average  \
# Earnings Date Stock Price                   0.998263              0.999301
# 45 Days Later Stock Price                   0.993276              0.995123
# Chaikin A/D line                            0.048192              0.047871
# ADX                                        -0.004144             -0.011896
# Aroon Up                                    0.014562              0.028335
# Aroon Down                                 -0.027647             -0.044218
# Lower Band                                  0.999305              0.998978
# Middle Band                                 1.000000              0.999282
# Upper Band                                  0.999443              0.998376
# Lower Band (5)                              0.998581              0.999635
# Middle Band (5)                             0.999282              1.000000
# Upper Band (5)                              0.999276              0.999678
# CCI                                         0.005452              0.021134
# Earnings Per Share                          0.750956              0.750948
# Forecasted Earnings Per Share               0.709698              0.710053
# % Surprise                                  0.075222              0.075121
# EMA (20 Day)                                0.999945              0.999465
# MACD_Hist                                   0.111904              0.142581
# MACD_Signal                                 0.164702              0.188158
# MACD                                        0.183034              0.213558
# OBV                                         0.023332              0.023340
# RSI                                         0.018934              0.038126
# 20 Day Moving Average                       1.000000              0.999282
# 5 Day Moving Average                        0.999282              1.000000
# SlowD                                       0.005307              0.022772
# SlowK                                      -0.004215              0.010359
#
#                                   SlowD     SlowK
# Earnings Date Stock Price      0.030758  0.024164
# 45 Days Later Stock Price      0.030671  0.021532
# Chaikin A/D line               0.028990  0.053429
# ADX                           -0.128304 -0.103669
# Aroon Up                       0.383344  0.340435
# Aroon Down                    -0.439639 -0.384187
# Lower Band                     0.008253 -0.001606
# Middle Band                    0.005307 -0.004215
# Upper Band                     0.002663 -0.006546
# Lower Band (5)                 0.025676  0.012945
# Middle Band (5)                0.022772  0.010359
# Upper Band (5)                 0.020029  0.007924
# CCI                            0.580563  0.677590
# Earnings Per Share             0.005207  0.001609
# Forecasted Earnings Per Share  0.008298  0.002447
# % Surprise                    -0.024970 -0.012815
# EMA (20 Day)                   0.007660 -0.002440
# MACD_Hist                      0.511038  0.502799
# MACD_Signal                    0.166888  0.115623
# MACD                           0.305678  0.256746
# OBV                           -0.003384  0.001083
# RSI                            0.634660  0.710644
# 20 Day Moving Average          0.005307 -0.004215
# 5 Day Moving Average           0.022772  0.010359
# SlowD                          1.000000  0.894062
# SlowK                          0.894062  1.000000
#
# [26 rows x 26 columns]

# %%
X = correlation_60[['Earnings Date Stock Price','20 Day Moving Average','5 Day Moving Average',
                  '% Surprise','Lower Band (5)','Upper Band (5)']]
y = correlation_60['60 Days Later Stock Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# 0.9845700581132735

# %%
results = model.predict(X_test)
df_results = pd.DataFrame({'Predictions': results, 'Actual': y_test, 'Stock Price': X_test['Earnings Date Stock Price']})
df_results.to_csv('results_60.csv')

# %%
correlation_15 = master_15_day.drop(['index','Stock Name','Reported Date','15 Days'],axis=1)
correlation_15.loc[correlation_15['15 Days Later Stock Price'] == 'NaN','15 Days Later Stock Price'] = np.nan
correlation_15 = correlation_15.dropna()

# %%
for x in correlation_15.columns:
    correlation_15[x] = pd.to_numeric(correlation_15[x])

# %%
X = correlation_15[['Earnings Date Stock Price','20 Day Moving Average','5 Day Moving Average',
                  '% Surprise','Lower Band (5)','Upper Band (5)']]
y = correlation_15['15 Days Later Stock Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# 0.9952193507294496

# %%
results = model.predict(X_test)
df_results = pd.DataFrame({'Predictions': results, 'Actual': y_test, 'Stock Price': X_test['Earnings Date Stock Price']})
df_results.to_csv('results_15.csv')

# %%
next_day = pd.read_sql('SELECT * FROM `Next Day Prices`',aconn)

# %%
new = pd.concat([master_45_day, next_day], axis=1, sort=False)
new.to_csv('new.csv')
new.head()
# Out:
#   index Stock Name Reported Date     45 Days Earnings Date Stock Price  \
# 0   0.0        AOS    04/25/2018  06/07/2018                      61.5
# 1   1.0        ABT    07/18/2018  08/30/2018                     64.75
# 2   2.0       ABBV    04/26/2018  06/08/2018                     97.44
# 3   3.0       ABMD    05/03/2018  06/15/2018                    335.57
# 4   4.0        ACN    06/28/2018  08/10/2018                     164.5
#
#   45 Days Later Stock Price Chaikin A/D line      ADX  Aroon Up Aroon Down  \
# 0                     63.75    22112351.7254  14.3637    4.0000   100.0000
# 1                     67.02  2576254096.7043  16.6408  100.0000    36.0000
# 2                    100.43   631659673.7910  43.6721    0.0000    32.0000
# 3                    443.58    79000339.1341  16.2327  100.0000    12.0000
# 4                    160.68  1104040811.2419  19.6501  100.0000    12.0000
#
#         ...           MACD             OBV      RSI 20 Day Moving Average  \
# 0       ...        -0.1845   27452026.0000  38.6725               63.8700
# 1       ...         0.4019  889111437.0000  66.6508               61.9205
# 2       ...        -2.6367  848408375.0000  52.1292               92.6640
# 3       ...         7.1604   48597232.0000  70.1965              301.3270
# 4       ...         0.6854  655922291.0000  61.3305              160.9530
#
#   5 Day Moving Average    SlowD    SlowK index Stock Name Next Day Prices
# 0              63.8120  33.1790  18.9226     0        AOS           62.65
# 1              63.0260  49.6140  50.3988     1        ABT           63.78
# 2              93.2880  41.1901  47.7973     2       ABBV           98.73
# 3             310.1800  80.2918  79.4982     3       ABMD          349.28
# 4             158.4980  21.2996  36.3666     4        ACN          163.59
#
# [5 rows x 33 columns]

# %%
new = new.drop(['index','Stock Name','Reported Date'],axis=1)
new.loc[new['45 Days Later Stock Price'] == 'N/A','45 Days Later Stock Price'] = np.nan
new.loc[new['Next Day Prices'] == 'N/A','Next Day Prices'] = np.nan
new = new.dropna()
new.head()
# Out:
#       45 Days Earnings Date Stock Price 45 Days Later Stock Price  \
# 0  06/07/2018                      61.5                     63.75
# 1  08/30/2018                     64.75                     67.02
# 2  06/08/2018                     97.44                    100.43
# 3  06/15/2018                    335.57                    443.58
# 4  08/10/2018                     164.5                    160.68
#
#   Chaikin A/D line      ADX  Aroon Up Aroon Down Lower Band Middle Band  \
# 0    22112351.7254  14.3637    4.0000   100.0000    61.3454     63.8700
# 1  2576254096.7043  16.6408  100.0000    36.0000    59.8854     61.9205
# 2   631659673.7910  43.6721    0.0000    32.0000    89.3459     92.6640
# 3    79000339.1341  16.2327  100.0000    12.0000   281.1875    301.3270
# 4  1104040811.2419  19.6501  100.0000    12.0000   155.8659    160.9530
#
#   Upper Band       ...       MACD_Hist MACD_Signal     MACD             OBV  \
# 0    66.3946       ...         -0.2088      0.0243  -0.1845   27452026.0000
# 1    63.9556       ...          0.2303      0.1715   0.4019  889111437.0000
# 2    95.9821       ...          1.0511     -3.6878  -2.6367  848408375.0000
# 3   321.4665       ...          1.6270      5.5334   7.1604   48597232.0000
# 4   166.0401       ...         -0.5045      1.1899   0.6854  655922291.0000
#
#        RSI 20 Day Moving Average 5 Day Moving Average    SlowD    SlowK  \
# 0  38.6725               63.8700              63.8120  33.1790  18.9226
# 1  66.6508               61.9205              63.0260  49.6140  50.3988
# 2  52.1292               92.6640              93.2880  41.1901  47.7973
# 3  70.1965              301.3270             310.1800  80.2918  79.4982
# 4  61.3305              160.9530             158.4980  21.2996  36.3666
#
#   Next Day Prices
# 0           62.65
# 1           63.78
# 2           98.73
# 3          349.28
# 4          163.59
#
# [5 rows x 28 columns]

# %%
new = new.drop(['45 Days'],axis=1)

# %%
X = new[['Next Day Prices','20 Day Moving Average', '5 Day Moving Average',
                  'Lower Band (5)','Earnings Per Share','Aroon Down','% Surprise']]
y = new['45 Days Later Stock Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# 0.992039209020839

# %%
results = model.predict(X_test)
df_results = pd.DataFrame({'Predictions': results, 'Actual': y_test, 'Stock Price': X_test['Next Day Prices']})
df_results.to_csv('results_test.csv')

# %%
next_day_45 = pd.read_csv('new.csv')

# %%
next_day_45_data = next_day_45.drop(['index','Stock Name','Reported Date','45 Days'],axis=1)
#next_day_45_data.loc[next_day_45_data['45 Days Later Stock Price'] == 'N/A','45 Days Later Stock Price'] = np.nan
#next_day_45_data.loc[next_day_45_data['Next Day Prices'] == 'N/A','Next Day Prices'] = np.nan
next_day_45_data = next_day_45_data.dropna()
# Out:
#       Unnamed: 0   index Stock Name Reported Date    45 Days  \
# 0              0     0.0        AOS     4/25/2018   6/7/2018
# 1              1     1.0        ABT     7/18/2018  8/30/2018
# 2              2     2.0       ABBV     4/26/2018   6/8/2018
# 3              3     3.0       ABMD      5/3/2018  6/15/2018
# 4              4     4.0        ACN     6/28/2018  8/10/2018
# 5              5     5.0       ATVI      5/3/2018  6/15/2018
# 6              6     6.0       ADBE     6/14/2018  7/27/2018
# 7              7     7.0        AAP     5/22/2018   7/6/2018
# 8              8     8.0        AMD     4/25/2018   6/7/2018
# 9              9     9.0        AES      5/8/2018  6/22/2018
# 10            10    10.0        AMG     4/30/2018  6/14/2018
# 11            11    11.0        AFL     4/25/2018   6/7/2018
# 12            12    12.0          A     5/14/2018  6/28/2018
# 13            13    13.0        APD     7/26/2018   9/7/2018
# 14            14    14.0       AKAM     4/30/2018  6/14/2018
# 15            15    15.0        ALK     4/23/2018   6/7/2018
# 16            16    16.0        ALB      5/9/2018  6/21/2018
# 17            17    17.0        ARE     4/30/2018  6/14/2018
# 18            18    18.0       ALXN     4/26/2018   6/8/2018
# 19            19    19.0       ALGN     7/25/2018   9/6/2018
# 20            20    20.0       ALLE     4/26/2018   6/8/2018
# 21            21    21.0        AGN     4/30/2018  6/14/2018
# 22            22    22.0        ADS     4/19/2018   6/1/2018
# 23            23    23.0        LNT      5/2/2018  6/14/2018
# 24            24    24.0        ALL      5/1/2018  6/15/2018
# 25            25    25.0         MO     4/26/2018   6/8/2018
# 26            26    26.0        AEE      5/9/2018  6/21/2018
# 27            27    27.0        AAL     4/26/2018   6/8/2018
# Middle Band (5)                     -0.352226         -0.018930  0.101019
# Upper Band (5)                      -0.331850         -0.045700  0.113877
# CCI                                  0.033071         -0.273060 -0.285825
# Earnings Per Share                  -0.045898         -0.025234  0.117811
# Forecasted Earnings Per Share       -0.024456         -0.070810  0.076264
# % Surprise                          -0.176495          0.065130  0.219276
# EMA (20 Day)                        -0.318478         -0.010674  0.131740
# MACD_Hist                           -0.271164         -0.359535 -0.002307
# MACD_Signal                         -0.195543          0.308351 -0.707179
# MACD                                -0.241640          0.138296 -0.572162
# OBV                                  0.173779         -0.214893  0.583019
# RSI                                 -0.109041         -0.092690 -0.420416
# 20 Day Moving Average               -0.305045         -0.004411  0.127943
# 5 Day Moving Average                -0.352226         -0.018930  0.101019
# SlowD                                0.027231         -0.534940  0.173008
# SlowK                                0.075475         -0.531458  0.108730
#
#                                Aroon Up  Aroon Down  Lower Band    ...     \
# Unnamed: 0                     0.014920    0.345413    0.105761    ...
# Earnings Date Stock Price     -0.249342   -0.110518    0.981653    ...
# 45 Days Later Stock Price     -0.270663   -0.158819    0.956806    ...
# Next Day Prices               -0.066256   -0.330539    0.662344    ...
# Percent Change                 0.022500    0.226037   -0.320313    ...
# Chaikin A/D line               0.113569   -0.244129    0.050201    ...
# ADX                           -0.402557    0.451684    0.056319    ...
# Aroon Up                       1.000000   -0.554319   -0.322495    ...
# Aroon Down                    -0.554319    1.000000   -0.043203    ...
# Lower Band                    -0.322495   -0.043203    1.000000    ...
# Middle Band                   -0.310672    0.005553    0.993178    ...
# Upper Band                    -0.297413    0.046598    0.976902    ...
# Lower Band (5)                -0.287116   -0.085807    0.992933    ...
# Middle Band (5)               -0.267061   -0.058864    0.989745    ...
# Upper Band (5)                -0.248523   -0.035388    0.982280    ...
# CCI                            0.646582   -0.387400   -0.551473    ...
# Earnings Per Share            -0.449813   -0.269246    0.622145    ...
# Forecasted Earnings Per Share -0.428130   -0.187005    0.628721    ...
# % Surprise                    -0.192481   -0.252900    0.217526    ...
# EMA (20 Day)                  -0.307854   -0.005292    0.992896    ...
# MACD_Hist                      0.398777   -0.368050   -0.403962    ...
# MACD_Signal                    0.578303   -0.685205   -0.407872    ...
# MACD                           0.590293   -0.667216   -0.454171    ...
# OBV                           -0.469611    0.167465   -0.020130    ...
# RSI                            0.642994   -0.588845   -0.361796    ...
# 20 Day Moving Average         -0.310672    0.005553    0.993178    ...
# 5 Day Moving Average          -0.267061   -0.058864    0.989745    ...
# SlowD                          0.086545    0.025927   -0.181254    ...
# SlowK                          0.188229   -0.025310   -0.279893    ...
#
#                                EMA (20 Day)  MACD_Hist  MACD_Signal      MACD  \
# Unnamed: 0                         0.179839   0.152841    -0.324266 -0.214897
# Earnings Date Stock Price          0.986317  -0.231964    -0.343081 -0.348772
# 45 Days Later Stock Price          0.951088  -0.234889    -0.302589 -0.316953
# Next Day Prices                    0.648634   0.070853     0.072080  0.080098
# Percent Change                    -0.318478  -0.271164    -0.195543 -0.241640
# Chaikin A/D line                  -0.010674  -0.359535     0.308351  0.138296
# ADX                                0.131740  -0.002307    -0.707179 -0.572162
# Aroon Up                          -0.307854   0.398777     0.578303  0.590293
# Aroon Down                        -0.005292  -0.368050    -0.685205 -0.667216
# Lower Band                         0.992896  -0.403962    -0.407872 -0.454171
# Middle Band                        0.999654  -0.386434    -0.472491 -0.500983
# Upper Band                         0.994759  -0.367563    -0.521964 -0.535140
# Lower Band (5)                     0.993072  -0.300500    -0.377268 -0.397533
# Middle Band (5)                    0.996681  -0.298348    -0.405864 -0.419978
# Upper Band (5)                     0.995034  -0.295072    -0.428545 -0.437296
# CCI                               -0.534766   0.748662     0.605881  0.720479
# Earnings Per Share                 0.588616  -0.148815    -0.162797 -0.177437
# Forecasted Earnings Per Share      0.579889  -0.266220    -0.189985 -0.235622
# % Surprise                         0.252503   0.263648    -0.050804  0.040275
# EMA (20 Day)                       1.000000  -0.365270    -0.464385 -0.487906
# MACD_Hist                         -0.365270   1.000000     0.505423  0.716817
# MACD_Signal                       -0.464385   0.505423     1.000000  0.963943
# MACD                              -0.487906   0.716817     0.963943  1.000000
# OBV                               -0.022522  -0.055403    -0.327374 -0.281634
# RSI                               -0.367206   0.741890     0.779842  0.858960
# 20 Day Moving Average              0.999654  -0.386434    -0.472491 -0.500983
# 5 Day Moving Average               0.996681  -0.298348    -0.405864 -0.419978
# SlowD                             -0.138548   0.583364     0.029474  0.203716
# SlowK                             -0.237006   0.607362     0.125273  0.288529
#
#                                     OBV       RSI  20 Day Moving Average  \
# Unnamed: 0                    -0.367240  0.020480               0.178650
# Earnings Date Stock Price     -0.040641 -0.246112               0.982491
# 45 Days Later Stock Price      0.006075 -0.259077               0.946708
# Next Day Prices               -0.112505 -0.015510               0.637360
# Percent Change                 0.173779 -0.109041              -0.305045
# Chaikin A/D line              -0.214893 -0.092690              -0.004411
# ADX                            0.583019 -0.420416               0.127943
# Aroon Up                      -0.469611  0.642994              -0.310672
# Aroon Down                     0.167465 -0.588845               0.005553
# Lower Band                    -0.020130 -0.361796               0.993178
# Middle Band                   -0.023075 -0.377361               1.000000
# Upper Band                    -0.025313 -0.386485               0.995156
# Lower Band (5)                -0.021716 -0.302261               0.990554
# Middle Band (5)               -0.041364 -0.297770               0.994849
# Upper Band (5)                -0.058080 -0.292485               0.993800
# CCI                           -0.261605  0.883385              -0.543699
# Earnings Per Share             0.458189 -0.240090               0.582259
# Forecasted Earnings Per Share  0.490466 -0.241434               0.577586
# % Surprise                     0.124320 -0.103537               0.239319
# EMA (20 Day)                  -0.022522 -0.367206               0.999654
# MACD_Hist                     -0.055403  0.741890              -0.386434
# MACD_Signal                   -0.327374  0.779842              -0.472491
# MACD                          -0.281634  0.858960              -0.500983
# OBV                            1.000000 -0.271539              -0.023075
# RSI                           -0.271539  1.000000              -0.377361
# 20 Day Moving Average         -0.023075 -0.377361               1.000000
# 5 Day Moving Average          -0.041364 -0.297770               0.994849
# SlowD                          0.089872  0.596243              -0.145471
# SlowK                          0.030587  0.676000              -0.242717
#
#                                5 Day Moving Average     SlowD     SlowK
# Unnamed: 0                                 0.180495  0.345924  0.389172
# Earnings Date Stock Price                  0.995650 -0.091508 -0.186611
# 45 Days Later Stock Price                  0.960586 -0.127810 -0.234544
# Next Day Prices                            0.679373 -0.141591 -0.226674
# Percent Change                            -0.352226  0.027231  0.075475
# Chaikin A/D line                          -0.018930 -0.534940 -0.531458
# ADX                                        0.101019  0.173008  0.108730
# Aroon Up                                  -0.267061  0.086545  0.188229
# Aroon Down                                -0.058864  0.025927 -0.025310
# Lower Band                                 0.989745 -0.181254 -0.279893
# Middle Band                                0.994849 -0.145471 -0.242717
# Upper Band                                 0.988610 -0.113761 -0.208803
# Lower Band (5)                             0.997022 -0.131657 -0.231884
# Middle Band (5)                            1.000000 -0.103301 -0.199516
# Upper Band (5)                             0.997794 -0.078399 -0.170701
# CCI                                       -0.481105  0.651977  0.735194
# Earnings Per Share                         0.593630 -0.145770 -0.219739
# Forecasted Earnings Per Share              0.577948 -0.089097 -0.176369
# % Surprise                                 0.271303 -0.140226 -0.169422
# EMA (20 Day)                               0.996681 -0.138548 -0.237006
# MACD_Hist                                 -0.298348  0.583364  0.607362
# MACD_Signal                               -0.405864  0.029474  0.125273
# MACD                                      -0.419978  0.203716  0.288529
# OBV                                       -0.041364  0.089872  0.030587
# RSI                                       -0.297770  0.596243  0.676000
# 20 Day Moving Average                      0.994849 -0.145471 -0.242717
# 5 Day Moving Average                       1.000000 -0.103301 -0.199516
# SlowD                                     -0.103301  1.000000  0.978421
# SlowK                                     -0.199516  0.978421  1.000000
#
# [29 rows x 29 columns]

# %%
next_day_45_data.loc[next_day_45_data['Percent Change'] > 1] = np.nan
next_day_45_data.loc[next_day_45_data['Percent Change'] > -.6] = np.nan
next_day_45_data = next_day_45_data.dropna()

# %%
X = next_day_45_data[['Next Day Prices','5 Day Moving Average',
                  'Chaikin A/D line','Aroon Down','% Surprise','OBV']]
y = next_day_45_data['Percent Change']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
model = LinearRegression()
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
testing_score
# Out:
# -0.24831894972225532

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Percent Change   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     51.34
# Date:                Mon, 06 May 2019   Prob (F-statistic):           1.87e-06
# Time:                        15:39:52   Log-Likelihood:                 45.168
# No. Observations:                  16   AIC:                            -76.34
# Df Residuals:                       9   BIC:                            -70.93
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.6692      0.019    -36.069      0.000      -0.711      -0.627
# Next Day Prices         -0.0008   5.35e-05    -15.459      0.000      -0.001      -0.001
# 5 Day Moving Average     0.0021      0.000      6.664      0.000       0.001       0.003
# Chaikin A/D line      8.351e-11   2.31e-11      3.608      0.006    3.11e-11    1.36e-10
# Aroon Down              -0.0003      0.000     -2.238      0.052      -0.001    3.55e-06
# % Surprise           -5.576e-05      0.000     -0.386      0.709      -0.000       0.000
# OBV                   2.751e-11   1.32e-11      2.082      0.067   -2.38e-12    5.74e-11
# ==============================================================================
# Omnibus:                        0.248   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.883   Jarque-Bera (JB):                0.426
# Skew:                          -0.022   Prob(JB):                        0.808
# Kurtosis:                       2.201   Cond. No.                     2.19e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
